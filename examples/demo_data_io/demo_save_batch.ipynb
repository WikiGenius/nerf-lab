# %% [markdown]
# # Experiment gathering data neglict color
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !python helper/demo_save_batch.py \
  --scene-dir ../../data/data_experiment2 \
  --total-poses 5 \
  --batch-size 5 \
  --radius 3.0 \
  --pose-method fibonacci \
  --seed 7 \
  --render-png \
  # --device cuda
# Out:
# [batch] wrote 5 frames → total 5
# ✅ Done. Scene written at: ../../data/data_experiment2

# %% [markdown]
# # This is method for storing 100 image takes 14.4 GB.
# - The bottelneck from ray .npyz
