# %%
# !python helper/demo_load_and_visualize.py \
  --scene-dir ./demo_scene \
  --split train \
  --num-frames 2 \
  --idx-render 0 \
  --show-world
# Out:
# Loading cfg_hash=9867679e2750, split=train, frames=['000000', '000001']
# Single frame: O shape=(307200, 3), C shape=(307200,), width=640, height=480
# Batched: H_wc=(2, 4, 4), O=(2, 307200, 3), C=(2, 307200)
# Figure(700x600)
# Figure(700x600)
# Figure(800x400)
# Figure(640x480)
# Figure(600x300)
# Picked row: 50228
